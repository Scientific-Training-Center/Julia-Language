# %% [markdown]
# https://docs.juliaplots.org/latest/tutorial/
#
# # Plot
# using Plots

# %%
using Plots
x = range(0, 10, length=100)
y = sin.(x)
plot(x, y)

# %%
using  BenchmarkTools

@benchmark sort(data) setup=(data=rand(10))
# Out:
# BenchmarkTools.Trial: 10000 samples with 832 evaluations.
#  Range (min … max):  102.885 ns …   5.832 μs  ┊ GC (min … max): 0.00% … 0.00%
#  Time  (median):     251.202 ns               ┊ GC (median):    0.00%
#  Time  (mean ± σ):   335.018 ns ± 265.582 ns  ┊ GC (mean ± σ):  1.00% ± 3.88%
#
#    ▃▆█▇▇▆▂▂
#   ▄█████████▇▆▇▆▆▆▅▅▅▄▄▄▄▄▄▄▃▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▂▂▂▂ ▄
#   103 ns           Histogram: frequency by time         1.28 μs <
#
#  Memory estimate: 144 bytes, allocs estimate: 1.

# %%
@btime y=sin(x) setup=(x=rand()) seconds=3
# Out:
#   5.200 ns (0 allocations: 0 bytes)
# 0.5355209431774091

# %%
y = @. sin(x).^2  
plot!(x, y)

# %%
savefig("myplot.png")
# Out:
# "c:\\Users\\EmilAGazazyan\\Repository\\Scientific Training Center\\Julia-Language\\Lessons\\Lesson 3\\myplot.png"

# %%
x = range(0, 10, length=100)
y1 = sin.(x)
y2 = cos.(x)
plot(x, [y1 y2], title="Trigonometric functions", label=["sin(x)" "cos(x)"], linewidth=3)

# %%
xlabel!("x")

# %%
x = range(0, 10, length=100)
y = sin.(x)
y_noisy = @. sin(x) + 0.1*randn()

plot(x, y, label="sin(x)")
plot!(x, y_noisy, seriestype=:scatter, label="data")

# %%
using Plots
x = range(0, 10, length=100)
y1 = @. exp(-0.1x) * cos(4x)
y2 = @. exp(-0.3x) * cos(4x)
y3 = @. exp(-0.5x) * cos(4x)
plot(x, [y1 y2 y3], layout=(2, 2), legend=false)

# %%
using Plots

x = randn(10^3)
histogram(x)

# %%
# Homework
using Plots
x=-1000000:0.1:1000000

a= -5:5
y=a'.*x.^2


plot(x,y)

# %%
using Plots
Cars = ["BMW", "Mersedes", "W",""];
Ps = [35, 45, 10, 10]
P = pie(Cars,Ps)
